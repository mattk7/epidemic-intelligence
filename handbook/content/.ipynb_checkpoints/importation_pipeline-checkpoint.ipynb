# %% [markdown]
# # Creating Importation Diagrams

# %%
from google.cloud import storage
import pandas as pd
import io
import os
import gzip
import plotly.express as px

# %%
service_account_id = 'elijahsandler@net-data-viz-handbook.iam.gserviceaccount.com'

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'C:\\Users\\elija\\Documents\\24f-coop\\net-data-viz-handbook-fe2c5531555d.json'

# %%
## Import data from Google Cloud

# Initialize a GCS client
client = storage.Client()

# Specify your bucket name and the specific .csv.gz file you want
bucket_name = 'gs_net-data-viz-handbook'
file_name = 'sample/importations/sample_SIR_importations_1.csv.gz'  # Update this to the specific file name

# Get the bucket and blob
bucket = client.get_bucket(bucket_name)
blob = bucket.blob(file_name)

# Download the .csv.gz file as bytes
compressed_content = blob.download_as_bytes()

# Decompress the .csv.gz content
with gzip.GzipFile(fileobj=io.BytesIO(compressed_content)) as gz:
    # Read the decompressed content into a pandas DataFrame
    df = pd.read_csv(gz)

# %%
# this is already formatted correctly! yay.
df
# Out:
#          source_basin  target_basin compartment  importations        date  \
# 0                1024          1361  Infectious             1  2009-04-09
# 1                1024          2217  Infectious             1  2009-04-29
# 2                1024          1034  Infectious             1  2009-05-10
# 3                1024          1018  Infectious             1  2009-05-13
# 4                1024          2125  Infectious             1  2009-05-14
# ...               ...           ...         ...           ...         ...
# 2174114          1928          3233  Infectious             1  2010-02-17
# 2174115          1890          3234  Infectious             1  2010-02-17
# 2174116          1462          3250  Infectious             1  2010-02-17
# 2174117          3244          3250  Infectious             1  2010-02-17
# 2174118          3247          3250  Infectious             1  2010-02-17
#
#          run_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 2174114       1
# 2174115       1
# 2174116       1
# 2174117       1
# 2174118       1
#
# [2174119 rows x 6 columns]

# %% [markdown]
# ## Fetching ID Map

# %%
url = '../data/gleam_geo_map.csv'
geo_map = pd.read_csv(url)
geo_map.head()
# Out:
#    basin_id   basin_label airport_code  latitude  longitude  country_id  \
# 0         0      Menongue          SPP  -14.6586    17.7214           2
# 1         1        Huambo          NOV  -12.8092    15.7608           2
# 2         2  M'BanzaCongo          SSY   -6.2697    14.2472           2
# 3         3          Soyo          SZA   -6.1411    12.3725           2
# 4         4       Lubango          SDD  -14.9247    13.5750           2
#
#   country_name country_iso3  region_id   region_label  continent_id  \
# 0       Angola          AGO          9  Middle Africa             0
# 1       Angola          AGO          9  Middle Africa             0
# 2       Angola          AGO          9  Middle Africa             0
# 3       Angola          AGO          9  Middle Africa             0
# 4       Angola          AGO          9  Middle Africa             0
#
#   continent_label  hemisphere_id     hemisphere_label
# 0          Africa              1  Tropical hemisphere
# 1          Africa              1  Tropical hemisphere
# 2          Africa              1  Tropical hemisphere
# 3          Africa              1  Tropical hemisphere
# 4          Africa              1  Tropical hemisphere

# %%
def map_basins(geography):
    m = dict(zip(geo_map['basin_id'], geo_map[geography]))
    return m

# %%
df['source_basin'].map(map_basins('country_name'))
# Out:
# 0                      Mexico
# 1                      Mexico
# 2                      Mexico
# 3                      Mexico
# 4                      Mexico
#                   ...
# 2174114    Russian Federation
# 2174115    Russian Federation
# 2174116               Ecuador
# 2174117                  Cuba
# 2174118                  Cuba
# Name: source_basin, Length: 2174119, dtype: object

# %% [markdown]
# ## Creating graphing dataframe by country

# %%
# get only columns we care about
df_data = df[['source_basin', 'target_basin', 'importations', 'date']]

# get basin names
df_data['source_basin_name'] = df_data['source_basin'].map(map_basins('basin_label'))
df_data['target_basin_name'] = df_data['target_basin'].map(map_basins('basin_label'))

# map basin to country
df_data['source_country_name'] = df_data['source_basin'].map(map_basins('country_name'))
df_data['target_country_name'] = df_data['target_basin'].map(map_basins('country_name'))

# map basin to continent
df_data['source_continent_name'] = df_data['source_basin'].map(map_basins('continent_label'))
df_data['target_continent_name'] = df_data['target_basin'].map(map_basins('continent_label'))


df_data.head()
# Out:
# C:\Users\elija\AppData\Local\Temp\ipykernel_40436\811835626.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    source_basin  target_basin  importations        date source_basin_name  \
# 0          1024          1361             1  2009-04-09        MexicoCity
# 1          1024          2217             1  2009-04-29        MexicoCity
# 2          1024          1034             1  2009-05-10        MexicoCity
# 3          1024          1018             1  2009-05-13        MexicoCity
# 4          1024          2125             1  2009-05-14        MexicoCity
#
#   target_basin_name source_country_name       target_country_name  \
# 0         Cartagena              Mexico                  Colombia
# 1           Chicago              Mexico  United States of America
# 2           Tijuana              Mexico                    Mexico
# 3          Leon(MX)              Mexico                    Mexico
# 4        Pittsburgh              Mexico  United States of America
#
#   source_continent_name target_continent_name
# 0         North America         South America
# 1         North America         North America
# 2         North America         North America
# 3         North America         North America
# 4         North America         North America

# %% [markdown]
# ## Seeing where cases are imported to/exported from in a country

# %%
df_data['source_country_name'].unique()
# Out:
# array(['Mexico', 'United States of America', 'Cuba', 'Spain', 'Sweden',
#        'France', 'Canada', 'Kenya', 'Italy', 'Portugal', 'Puerto Rico',
#        'Colombia', 'Israel', 'Virgin Islands (U.S.)', 'United Kingdom',
#        'Korea, Rep.', 'Peru', 'Dominican Republic', 'Greece', 'Japan',
#        'Germany', 'United Arab Emirates', 'Brazil', 'Luxembourg', 'China',
#        'Ireland', 'India', 'Russian Federation', 'Argentina', 'Qatar',
#        'Lithuania', 'Costa Rica', 'Belgium', 'Bahamas', 'Iceland',
#        'Singapore', 'Chile', 'Trinidad and Tobago', 'Saudi Arabia',
#        'Switzerland', 'Croatia', 'Cayman Islands', 'Ecuador', 'Australia',
#        'Taiwan', 'Panama', 'Netherlands', 'Latvia', 'Austria', 'Jamaica',
#        'Norway', 'Belize', 'Thailand', 'Cambodia', 'Hungary', 'Poland',
#        'Turks and Caicos Islands', 'Denmark', 'Guatemala', 'South Africa',
#        'Finland', 'Turkey', 'Guam', 'Macedonia', 'Maldives', 'Malaysia',
#        'Ukraine', 'Aruba', 'Philippines', 'Uruguay', 'Tunisia',
#        'Czech Republic', 'Malta', 'Bolivia', 'Kosovo', 'Paraguay',
#        'Kazakhstan', 'Cyprus', 'Egypt, Arab Rep.', 'St. Maarten',
#        'Northern Mariana Islands', 'Slovenia', 'Vietnam', 'Kuwait',
#        'Romania', 'Serbia', 'New Zealand', 'Venezuela', 'Estonia',
#        'Indonesia', 'Honduras', 'Lebanon', 'Bermuda', 'El Salvador',
#        'Barbados', 'Cape Verde', 'Morocco', 'Jordan', 'Bahrain',
#        'Mongolia', 'St. Kitts and Nevis', 'Uzbekistan',
#        'Marshall Islands', 'Pakistan', 'Oman', 'Algeria', 'Palau',
#        'Angola', 'Montenegro', 'Iran', 'Guadeloupe', 'Sri Lanka',
#        'Cyprus, Northern', 'Bulgaria', 'Samoa',
#        'St. Vincent and Grenadines', 'Curaçao', 'Lao PDR',
#        'Antigua and Barbuda', 'Jersey', 'Nepal', 'Seychelles', 'Georgia',
#        'Kyrgyzstan', 'French Polynesia', 'Fiji', 'Namibia', 'Guyana',
#        'Ghana', 'Albania', 'Zanzibar', 'Reunion', 'Belarus',
#        'Slovak Republic', 'Bosnia and Herzegovina', 'Bangladesh',
#        'Ethiopia', 'Gibraltar', 'Svalbard Islands', 'Botswana',
#        'Mauritius', 'Dominica', 'Myanmar', 'Grenada', 'Martinique',
#        'Faeroe Islands', 'Rwanda', 'Moldova', 'St. Lucia', 'Azerbaijan',
#        'St-Barthélemy', 'Equatorial Guinea', 'Eritrea', 'Guernsey',
#        'Armenia', 'Caribbean Netherlands', 'Gabon', 'Zimbabwe', 'Sudan',
#        'Tonga', 'Nigeria', 'Brunei', 'São Tomé and Principe',
#        'Afghanistan', 'New Caledonia', 'Zambia', 'Nicaragua',
#        'Isle of Man', 'Vanuatu', 'Papua New Guinea', 'Mali', 'Monaco',
#        'Congo, Dem. Rep.', 'Micronesia, Fed. States of', 'Madagascar',
#        'Greenland', "Côte d'Ivoire", 'French Guiana', 'Senegal',
#        'Norfolk Island', 'British Virgin Islands',
#        'St. Pierre and Miquelon', 'Haiti', 'Djibouti', 'Timor-Leste',
#        'Congo, Rep.', 'Uganda', 'Cameroon', 'Iraq', 'Syria', 'Benin',
#        'Togo', 'Kiribati', 'Mayotte', 'Somalia', 'Gambia', 'Comoros',
#        'Guinea', 'Cook Islands', 'Suriname', 'Aland Islands',
#        'American Samoa', 'Christmas Island', 'Turkmenistan',
#        'South Sudan', 'Tajikistan', 'Mauritania', 'Chad', 'Yemen',
#        'Mozambique', 'Guinea-Bissau', 'Libya', 'Anguilla', 'Niger',
#        'Wallis and Futuna Islands', 'Cocos (Keeling) Islands', 'Liberia',
#        'Sierra Leone', 'Niue', 'Solomon Islands', 'Nauru',
#        'Falkland Islands', 'Burkina Faso', 'Malawi', 'Bhutan',
#        'Montserrat', 'Central African Republic', 'Burundi', 'Tuvalu'],
#       dtype=object)

# %%
country='Korea, Rep.'

# getting only rows where country is the origin
country_export = df_data[df_data['source_country_name'] == country]

# group by date and origin city
df_country_exports = country_export[['source_basin_name', 'date', 'importations']]\
.groupby(['source_basin_name', 'date']).sum().reset_index()

# Create the area plot
fig = px.area(df_country_exports, x='date', y='importations', title=f'Exportations from {country}', 
              color='source_basin_name',
              labels={
                     "importations": "Cases Exported",
                     "date": "Date",
                     "source_basin_name": "Source"
                 },)
fig.show()
# Out:
# <div>                            <div id="801adb81-58aa-4b17-81e1-797b583ee2ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Daegu","orientation":"v","showlegend":true,"stackgroup":"1","x":["2009-08-01","2009-09-03","2009-09-04","2009-09-16","2009-09-22","2009-09-23","2009-09-24","2009-09-26","2009-09-27","2009-09-28","2009-09-30","2009-10-01","2009-10-02","2009-10-03","2009-10-04","2009-10-05","2009-10-06","2009-10-07","2009-10-08","2009-10-09","2009-10-10","2009-10-11","2009-10-12","2009-10-13","2009-10-14","2009-10-15","2009-10-16","2009-10-17","2009-10-18","2009-10-19","2009-10-20","2009-10-21","2009-10-22","2009-10-23","2009-10-24","2009-10-25","2009-10-26","2009-10-27","2009-10-28","2009-10-29","2009-10-30","2009-10-31","2009-11-01","2009-11-02","2009-11-03","2009-11-04","2009-11-05","2009-11-06","2009-11-07","2009-11-08","2009-11-09","2009-11-10","2009-11-11","2009-11-12","2009-11-13","2009-11-14","2009-11-15","2009-11-16","2009-11-17","2009-11-18","2009-11-19","2009-11-20","2009-11-21","2009-11-22","2009-11-23","2009-11-24","2009-11-25","2009-11-26","2009-11-27","2009-11-28","2009-11-29","2009-11-30","2009-12-01","2009-12-02","2009-12-03","2009-12-04","2009-12-05","2009-12-06","2009-12-07","2009-12-08","2009-12-09","2009-12-10","2009-12-11","2009-12-12","2009-12-13","2009-12-14","2009-12-15","2009-1 ...

# %% [markdown]
# Note that this also works for seeing where cases are being imported from: just filter from `target_country_name`, and change the relevant column names in the following lines. We can also filter out cases sent to the country itself so that we only see international imports, maybe even group by continent to make it a little easier to look at, or make any other filters we'd like before graphing. Plotly is really nice because it has a GUI, so we can select a date range to look at and deselect countries after making the plot if we'd like to.

# %%
country='United States of America'

# getting only rows where country is the target
country_export = df_data[df_data['target_country_name'] == country]

# exclude cases where source and target are the same
country_export = country_export[country_export['source_country_name'] != country]

# group by date and source continent (the world is a big place and that's a lot of basins)
df_country_exports = country_export[['source_continent_name', 'date', 'importations']]\
.groupby(['source_continent_name', 'date']).sum().reset_index()

# Create the area plot
fig = px.area(df_country_exports, x='date', y='importations', title=f'International Importations to {country}', 
              color='source_continent_name',
              labels={
                     "importations": "Cases Imported",
                     "date": "Date",
                     "source_continent_name": "Source"
                 },)
fig.show()
# Out:
# <div>                            <div id="a813b562-0671-4e47-9f47-a3dbc38c6fae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a813b562-0671-4e47-9f47-a3dbc38c6fae")) {                    Plotly.newPlot(                        "a813b562-0671-4e47-9f47-a3dbc38c6fae",                        [{"fillpattern":{"shape":""},"hovertemplate":"Source=Africa<br>Date=%{x}<br>Cases Imported=%{y}<extra></extra>","legendgroup":"Africa","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Africa","orientation":"v","showlegend":true,"stackgroup":"1","x":["2009-09-23","2009-09-26","2009-09-28","2009-09-30","2009-10-01","2009-10-04","2009-10-09","2009-10-13","2009-10-14","2009-10-17","2009-10-19","2009-10-20","2009-10-21","2009-10-23","2009-10-24","2009-10-25","2009-10-26","2009-10-27","2009-10-31","2009-11-02","2009-11-03","2009-11-04","2009-11-05","2009-11-06","2009-11-07","2009-11-08","2009-11-09","2009-11-10","2009-11-11","2009-11-12","2009-11-15","2009-11-16","2009-11-17","